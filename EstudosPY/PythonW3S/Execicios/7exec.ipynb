# %% [markdown]
# Claro, aqui estão alguns exercícios para você praticar com loops `for` em Python:
#
# ### Exercício 1: Iteração Simples
# 1. Crie uma lista chamada `numeros` contendo os números de 1 a 10.
# 2. Use um loop `for` para iterar sobre a lista e imprimir cada número.
#
# ### Exercício 2: Soma de Números
# 1. Crie uma lista chamada `numeros` contendo os números de 1 a 10.
# 2. Use um loop `for` para somar todos os números na lista.
# 3. Imprima a soma total após o loop.
#
# ### Exercício 3: Iteração sobre String
# 1. Crie uma string chamada `palavra` com o valor "Python".
# 2. Use um loop `for` para iterar sobre cada caractere da string e imprimir cada caractere em uma nova linha.
#
# ### Exercício 4: Iteração com Range
# 1. Use um loop `for` com a função `range` para imprimir os números de 0 a 9.
#
# ### Exercício 5: List Comprehension
# 1. Use uma compreensão de lista (list comprehension) para criar uma lista contendo os quadrados dos números de 1 a 10.
# 2. Imprima a lista resultante.
#
# ### Exercício 6: Iteração sobre Dicionário
# 1. Crie um dicionário chamado `aluno` com as seguintes chaves e valores:
#    - `nome`: "João"
#    - `idade`: 20
#    - `curso`: "Engenharia"
# 2. Use um loop `for` para iterar sobre os itens do dicionário e imprimir cada chave e valor.
#
# ### Exercício 7: Iteração com Enumerate
# 1. Crie uma lista chamada `frutas` contendo as frutas: "maçã", "banana", "cereja".
# 2. Use a função `enumerate` em um loop `for` para iterar sobre a lista e imprimir o índice e a fruta correspondente.
#
# ### Exercício 8: Iteração com Break
# 1. Crie uma lista chamada `numeros` contendo os números de 1 a 10.
# 2. Use um loop `for` para iterar sobre a lista.
# 3. Quando encontrar o número 5, interrompa o loop usando a instrução `break`.
# 4. Imprima uma mensagem indicando que o número 5 foi encontrado e o loop foi interrompido.
#
# ### Exercício 9: Iteração com Continue
# 1. Crie uma lista chamada `numeros` contendo os números de 1 a 10.
# 2. Use um loop `for` para iterar sobre a lista.
# 3. Quando encontrar o número 5, pule a iteração atual usando a instrução `continue`.
# 4. Imprima cada número, exceto o número 5.
#
# ### Exercício 10: Iteração sobre Lista de Listas
# 1. Crie uma lista chamada `matriz` contendo as seguintes listas internas: [1, 2, 3], [4, 5, 6], [7, 8, 9].
# 2. Use um loop `for` para iterar sobre as listas internas e imprimir cada elemento da matriz.
#
# ### Dicas de Implementação
#
# Para resolver esses exercícios, você pode criar um novo arquivo Python ou usar um ambiente de desenvolvimento como Jupyter Notebook. Teste cada parte do seu código para garantir que você entendeu como trabalhar com loops `for` em Python.
#
# Se tiver dúvidas ou precisar de ajuda com algum exercício, estarei aqui para ajudar!
